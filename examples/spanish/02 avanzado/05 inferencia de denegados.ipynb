# %% [markdown]
# Vemos como desarrollar un modelo usando el `parceling` para la inferencia de denegados

# %% [markdown]
# <span style='color:blue'>Importamos los módulos

# %%
import sys, numpy as np, pandas as pd, memento as me

# %% [markdown]
# <span style='color:blue'>Cargamos los datos

# %%
df = pd.read_csv('hmeq.csv')

# %% [markdown]
# <span style='color:blue'>Ponemos las columnas en minúsculas, renombramos el target a `target_original` y añadimos un `id`

# %%
df.columns = ['target_original'] + [col.lower() for col in df.columns[1:]]
df.insert(0, 'id', [str(i).zfill(4) for i in range(1, len(df)+1)])

# %% [markdown]
# <span style='color:blue'>Generamos los denegados aleatoriamente (esto no debería ser así porque en general los denegados tienen un peor perfil... pero bueno es un ejemplo) marcando como denegados al 25% de la muestra

# %%
mask_rejected = np.array([True]*round(len(df)*0.75)+[False]*(len(df)-round(len(df)*0.75)))
np.random.seed(123) # Importante fijar semilla para que sea replicable
np.random.shuffle(mask_rejected)
df['decision'] = np.where(mask_rejected, 'aprobado', 'denegado')
df['target'] = np.where(mask_rejected, df['target_original'], -3)
df.head()
# Out:
#      id  target_original  loan  mortdue     value   reason     job   yoj  \
# 0  0001                1  1100  25860.0   39025.0  HomeImp   Other  10.5
# 1  0002                1  1300  70053.0   68400.0  HomeImp   Other   7.0
# 2  0003                1  1500  13500.0   16700.0  HomeImp   Other   4.0
# 3  0004                1  1500      NaN       NaN      NaN     NaN   NaN
# 4  0005                0  1700  97800.0  112000.0  HomeImp  Office   3.0
#
#    derog  delinq       clage  ninq  clno  debtinc  decision  target
# 0    0.0     0.0   94.366667   1.0   9.0      NaN  aprobado       1
# 1    0.0     2.0  121.833333   0.0  14.0      NaN  aprobado       1
# 2    0.0     0.0  149.466667   1.0  10.0      NaN  aprobado       1
# 3    NaN     NaN         NaN   NaN   NaN      NaN  aprobado       1
# 4    0.0     0.0   93.333333   0.0  14.0      NaN  denegado      -3

# %% [markdown]
# <span style='color:blue'>Vemos la distribución de denegados, buenos y malos que tenemos

# %%
me.proc_freq(df, 'decision', 'target')
# Out:
# target      -3     0    1
# decision
# aprobado     0  3567  903
# denegado  1490     0    0

# %% [markdown]
# <span style='color:blue'>Lo primero es sacar una scorecard solo con aceptados

# %%
df_aceptados = df[df.decision == 'aprobado']
X, y = df_aceptados.drop('target', axis=1), df_aceptados.target.values
modelo_aceptados = me.Scorecard(excluded_vars=['id', 'target_original', 'decision']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (14) superior al número de variables candidatas (11)
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.565534 | pv = 0.00e+00 | Gini train = 68.93% | Gini test = 66.22% ---> Feature selected: debtinc
# Step 02 | 0:00:00.491939 | pv = 1.77e-36 | Gini train = 76.58% | Gini test = 72.63% ---> Feature selected: delinq
# Step 03 | 0:00:00.568667 | pv = 5.14e-27 | Gini train = 81.30% | Gini test = 76.92% ---> Feature selected: clage
# Step 04 | 0:00:00.672944 | pv = 1.39e-21 | Gini train = 84.13% | Gini test = 78.25% ---> Feature selected: value
# Step 05 | 0:00:00.585246 | pv = 1.42e-12 | Gini train = 84.96% | Gini test = 79.30% ---> Feature selected: derog
# Step 06 | 0:00:00.562452 | pv = 8.26e-07 | Gini train = 85.44% | Gini test = 79.76% ---> Feature selected: clno
# Step 07 | 0:00:00.522711 | pv = 4.87e-06 | Gini train = 86.09% | Gini test = 80.29% ---> Feature selected: job
# ------------------------------------------------------------------------------------------------------------------------
# En el siguiente paso ni el KS ni el GINI del train suben más de un 0.20 o un 0.30 respectivamente, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['debtinc', 'delinq', 'clage', 'value', 'derog', 'clno', 'job']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 70.72% de KS y un 86.09% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 64.59% de KS y un 80.29% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Con esta scorecard de aceptados vamos a inferir cual hubiera sido el target de los denegados

# %%
prediction = modelo_aceptados.predict(df, keep_columns=['id'])[['id', 'scorecardpoints']]
df2 = df.merge(prediction.rename(columns={'scorecardpoints': 'scorecardpoints_acep'}), 'left', 'id')

# %% [markdown]
# <span style='color:blue'>Aplicamos el parceling

# %%
df3, c = me.parceling(df2)

# %% [markdown]
# <span style='color:blue'>Teniendo los denegados ya un target inferido desarrollamos otra scorecard con una nueva partición 70-30 (usando todo: aceptados + denegados)

# %%
X_def, y_def = df3[X.columns], df3.target_def
modelo_def = me.Scorecard(
    excluded_vars=['id', 'target_original', 'decision'], save_tables='all'
).fit(X_def, y_def)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (14) superior al número de variables candidatas (11)
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.397887 | pv = 0.00e+00 | Gini train = 67.53% | Gini test = 67.49% ---> Feature selected: debtinc
# Step 02 | 0:00:00.543674 | pv = 4.65e-42 | Gini train = 74.84% | Gini test = 75.90% ---> Feature selected: delinq
# Step 03 | 0:00:00.589229 | pv = 1.37e-34 | Gini train = 79.47% | Gini test = 79.77% ---> Feature selected: clage
# Step 04 | 0:00:00.628488 | pv = 6.20e-25 | Gini train = 82.06% | Gini test = 81.78% ---> Feature selected: value
# Step 05 | 0:00:00.759892 | pv = 3.14e-18 | Gini train = 82.95% | Gini test = 81.47% ---> Feature selected: derog
# Step 06 | 0:00:00.710140 | pv = 1.03e-07 | Gini train = 83.48% | Gini test = 82.31% ---> Feature selected: job
# Step 07 | 0:00:00.673464 | pv = 1.10e-05 | Gini train = 83.88% | Gini test = 82.23% ---> Feature selected: clno
# ------------------------------------------------------------------------------------------------------------------------
# En el siguiente paso ni el KS ni el GINI del train suben más de un 0.20 o un 0.30 respectivamente, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['debtinc', 'delinq', 'clage', 'value', 'derog', 'job', 'clno']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 68.94% de KS y un 83.88% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 69.42% de KS y un 82.23% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Evaluamos el modelo también solo sobre los aceptados (en el 70-30 del último modelo)

# %%
data_train = modelo_def.X_train.copy()
data_train['target'] = modelo_def.y_train
data_train_oa = data_train[data_train.decision == 'aprobado'].reset_index(drop=True)
data_train_final_oa = modelo_def.predict(data_train_oa, target_name='target')
ks_train, gini_train = me.compute_metrics(data_train_final_oa, 'target', ['gini', 'ks'], True)
print('-'*80)
data_test = modelo_def.X_test.copy()
data_test['target'] = modelo_def.y_test
data_test_oa = data_test[data_test.decision == 'aprobado'].reset_index(drop=True)
data_test_final_oa = modelo_def.predict(data_test_oa, target_name='target')
ks_test, gini_test = me.compute_metrics(data_test_final_oa, 'target', ['gini', 'ks'], True)
# Out:
# El  modelo tiene un 69.64% de KS y un 84.26% de Gini en esta muestra
# --------------------------------------------------------------------------------
# El  modelo tiene un 71.04% de KS y un 83.38% de Gini en esta muestra

# %% [markdown]
# <span style='color:blue'>Mostramos la scorecard final

# %%
me.pretty_scorecard(modelo_def)
# Out:
# <style type="text/css">
# #T_bef91_row0_col0, #T_bef91_row0_col1, #T_bef91_row0_col2, #T_bef91_row0_col3, #T_bef91_row0_col4, #T_bef91_row0_col5, #T_bef91_row0_col6, #T_bef91_row0_col7, #T_bef91_row0_col8, #T_bef91_row0_col9, #T_bef91_row0_col10, #T_bef91_row1_col0, #T_bef91_row1_col1, #T_bef91_row1_col2, #T_bef91_row1_col3, #T_bef91_row1_col4, #T_bef91_row1_col5, #T_bef91_row1_col6, #T_bef91_row1_col7, #T_bef91_row1_col8, #T_bef91_row1_col9, #T_bef91_row1_col10, #T_bef91_row2_col0, #T_bef91_row2_col1, #T_bef91_row2_col2, #T_bef91_row2_col3, #T_bef91_row2_col4, #T_bef91_row2_col5, #T_bef91_row2_col6, #T_bef91_row2_col7, #T_bef91_row2_col8, #T_bef91_row2_col9, #T_bef91_row2_col10, #T_bef91_row3_col0, #T_bef91_row3_col1, #T_bef91_row3_col2, #T_bef91_row3_col3, #T_bef91_row3_col4, #T_bef91_row3_col5, #T_bef91_row3_col6, #T_bef91_row3_col7, #T_bef91_row3_col8, #T_bef91_row3_col9, #T_bef91_row3_col10, #T_bef91_row4_col0, #T_bef91_row4_col1, #T_bef91_row4_col2, #T_bef91_row4_col3, #T_bef91_row4_col4, #T_bef91_row4_col5, #T_bef91_row4_col6, #T_bef91_row4_col7, #T_bef91_row4_col8, #T_bef91_row4_col9, #T_bef91_row4_col10, #T_bef91_row5_col0, #T_bef91_row5_col1, #T_bef91_row5_col2, #T_bef91_row5_col3, #T_bef91_row5_col4, #T_bef91_row5_col5, #T_bef91_row5_col6, #T_bef91_row5_col7, #T_bef91_row5_col8, #T_bef91_row5_col9, #T_bef91_row5_col10, #T_bef91_row10_col0, #T_bef91_row10_col1, #T_bef91_row10_col2, #T_bef91_row10_col3, #T_bef91_row10_col4, #T_bef91_row10_col5, #T_bef91_row10_col6, #T_bef91_row10_col7, #T_bef91_row10_col8, #T_bef91_row10_col9, #T_bef91_row10_col10, #T_bef91_row11_col0, #T_bef91_row11_col1, #T_bef91_row11_col2, #T_bef91_row11_col3, #T_bef91_row11_col4, #T_bef91_row11_col5, #T_bef91_row11_col6, #T_bef91_row11_col7, #T_bef91_row11_col8, #T_bef91_row11_col9, #T_bef91_row11_col10, #T_bef91_row12_col0, #T_bef91_row12_col1, #T_bef91_row12_col2, #T_bef91_row12_col3, #T_bef91_row12_col4, #T_bef91_row12_col5, #T_bef91_row12_col6, #T_bef91_row12_col7, #T_bef91_row12_col8, #T_bef91_row12_col9, #T_bef91_row12_col10, #T_bef91_row13_col0, #T_bef91_row13_col1, #T_bef91_row13_col2, #T_bef91_row13_col3, #T_bef91_row13_col4, #T_bef91_row13_col5, #T_bef91_row13_col6, #T_bef91_row13_col7, #T_bef91_row13_col8, #T_bef91_row13_col9, #T_bef91_row13_col10, #T_bef91_row14_col0, #T_bef91_row14_col1, #T_bef91_row14_col2, #T_bef91_row14_col3, #T_bef91_row14_col4, #T_bef91_row14_col5, #T_bef91_row14_col6, #T_bef91_row14_col7, #T_bef91_row14_col8, #T_bef91_row14_col9, #T_bef91_row14_col10, #T_bef91_row15_col0, #T_bef91_row15_col1, #T_bef91_row15_col2, #T_bef91_row15_col3, #T_bef91_row15_col4, #T_bef91_row15_col5, #T_bef91_row15_col6, #T_bef91_row15_col7, #T_bef91_row15_col8, #T_bef91_row15_col9, #T_bef91_row15_col10, #T_bef91_row22_col0, #T_bef91_row22_col1, #T_bef91_row22_col2, #T_bef91_row22_col3, #T_bef91_row22_col4, #T_bef91_row22_col5, #T_bef91_row22_col6, #T_bef91_row22_col7, #T_bef91_row22_col8, #T_bef91_row22_col9, #T_bef91_row22_col10, #T_bef91_row23_col0, #T_bef91_row23_col1, #T_bef91_row23_col2, #T_bef91_row23_col3, #T_bef91_row23_col4, #T_bef91_row23_col5, #T_bef91_row23_col6, #T_bef91_row23_col7, #T_bef91_row23_col8, #T_bef91_row23_col9, #T_bef91_row23_col10, #T_bef91_row24_col0, #T_bef91_row24_col1, #T_bef91_row24_col2, #T_bef91_row24_col3, #T_bef91_row24_col4, #T_bef91_row24_col5, #T_bef91_row24_col6, #T_bef91_row24_col7, #T_bef91_row24_col8, #T_bef91_row24_col9, #T_bef91_row24_col10, #T_bef91_row25_col0, #T_bef91_row25_col1, #T_bef91_row25_col2, #T_bef91_row25_col3, #T_bef91_row25_col4, #T_bef91_row25_col5, #T_bef91_row25_col6, #T_bef91_row25_col7, #T_bef91_row25_col8, #T_bef91_row25_col9, #T_bef91_row25_col10, #T_bef91_row30_col0, #T_bef91_row30_col1, #T_bef91_row30_col2, #T_bef91_row30_col3, #T_bef91_row30_col4, #T_bef91_row30_col5, #T_bef91_row30_col6, #T_bef91_row30_col7, #T_bef91_row30_col8, #T_bef91_row30_col9, #T_bef91_row30_col10, #T_bef91_row31_col0, #T_bef91_row31_col1, #T_bef91_row31_col2, #T_bef91_row31_col3, #T_bef91_row31_col4, #T_bef91_row31_co ...
#   background-color: #CCECFF;
# }
# #T_bef91_row6_col0, #T_bef91_row6_col1, #T_bef91_row6_col2, #T_bef91_row6_col3, #T_bef91_row6_col4, #T_bef91_row6_col5, #T_bef91_row6_col6, #T_bef91_row6_col7, #T_bef91_row6_col8, #T_bef91_row6_col9, #T_bef91_row6_col10, #T_bef91_row7_col0, #T_bef91_row7_col1, #T_bef91_row7_col2, #T_bef91_row7_col3, #T_bef91_row7_col4, #T_bef91_row7_col5, #T_bef91_row7_col6, #T_bef91_row7_col7, #T_bef91_row7_col8, #T_bef91_row7_col9, #T_bef91_row7_col10, #T_bef91_row8_col0, #T_bef91_row8_col1, #T_bef91_row8_col2, #T_bef91_row8_col3, #T_bef91_row8_col4, #T_bef91_row8_col5, #T_bef91_row8_col6, #T_bef91_row8_col7, #T_bef91_row8_col8, #T_bef91_row8_col9, #T_bef91_row8_col10, #T_bef91_row9_col0, #T_bef91_row9_col1, #T_bef91_row9_col2, #T_bef91_row9_col3, #T_bef91_row9_col4, #T_bef91_row9_col5, #T_bef91_row9_col6, #T_bef91_row9_col7, #T_bef91_row9_col8, #T_bef91_row9_col9, #T_bef91_row9_col10, #T_bef91_row16_col0, #T_bef91_row16_col1, #T_bef91_row16_col2, #T_bef91_row16_col3, #T_bef91_row16_col4, #T_bef91_row16_col5, #T_bef91_row16_col6, #T_bef91_row16_col7, #T_bef91_row16_col8, #T_bef91_row16_col9, #T_bef91_row16_col10, #T_bef91_row17_col0, #T_bef91_row17_col1, #T_bef91_row17_col2, #T_bef91_row17_col3, #T_bef91_row17_col4, #T_bef91_row17_col5, #T_bef91_row17_col6, #T_bef91_row17_col7, #T_bef91_row17_col8, #T_bef91_row17_col9, #T_bef91_row17_col10, #T_bef91_row18_col0, #T_bef91_row18_col1, #T_bef91_row18_col2, #T_bef91_row18_col3, #T_bef91_row18_col4, #T_bef91_row18_col5, #T_bef91_row18_col6, #T_bef91_row18_col7, #T_bef91_row18_col8, #T_bef91_row18_col9, #T_bef91_row18_col10, #T_bef91_row19_col0, #T_bef91_row19_col1, #T_bef91_row19_col2, #T_bef91_row19_col3, #T_bef91_row19_col4, #T_bef91_row19_col5, #T_bef91_row19_col6, #T_bef91_row19_col7, #T_bef91_row19_col8, #T_bef91_row19_col9, #T_bef91_row19_col10, #T_bef91_row20_col0, #T_bef91_row20_col1, #T_bef91_row20_col2, #T_bef91_row20_col3, #T_bef91_row20_col4, #T_bef91_row20_col5, #T_bef91_row20_col6, #T_bef91_row20_col7, #T_bef91_row20_col8, #T_bef91_row20_col9, #T_bef91_row20_col10, #T_bef91_row21_col0, #T_bef91_row21_col1, #T_bef91_row21_col2, #T_bef91_row21_col3, #T_bef91_row21_col4, #T_bef91_row21_col5, #T_bef91_row21_col6, #T_bef91_row21_col7, #T_bef91_row21_col8, #T_bef91_row21_col9, #T_bef91_row21_col10, #T_bef91_row26_col0, #T_bef91_row26_col1, #T_bef91_row26_col2, #T_bef91_row26_col3, #T_bef91_row26_col4, #T_bef91_row26_col5, #T_bef91_row26_col6, #T_bef91_row26_col7, #T_bef91_row26_col8, #T_bef91_row26_col9, #T_bef91_row26_col10, #T_bef91_row27_col0, #T_bef91_row27_col1, #T_bef91_row27_col2, #T_bef91_row27_col3, #T_bef91_row27_col4, #T_bef91_row27_col5, #T_bef91_row27_col6, #T_bef91_row27_col7, #T_bef91_row27_col8, #T_bef91_row27_col9, #T_bef91_row27_col10, #T_bef91_row28_col0, #T_bef91_row28_col1, #T_bef91_row28_col2, #T_bef91_row28_col3, #T_bef91_row28_col4, #T_bef91_row28_col5, #T_bef91_row28_col6, #T_bef91_row28_col7
