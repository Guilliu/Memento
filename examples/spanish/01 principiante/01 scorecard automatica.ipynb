# %% [markdown]
# En este notebook se muestra cómo sacar un modelo automático con la clase `scorecard` en un dataset de juguete

# %% [markdown]
# <span style='color:blue'>Importamos los módulos

# %%
import sys, pandas as pd, memento as me

# %% [markdown]
# <span style='color:blue'>Cargamos los datos separando las variables predictoras (guardadas en X) de la variable objetivo (guardada en y)

# %%
from sklearn.datasets import load_breast_cancer as lbc
X, y = pd.DataFrame(lbc().data, columns=lbc().feature_names), lbc().target

# %% [markdown]
# <span style='color:blue'>Sustituimos los espacios en blanco por guiones bajos en el nombre de las columnas

# %%
X.columns = [i.replace(' ', '_') for i in X.columns]

# %% [markdown]
# <span style='color:blue'>Todas las variables predictoras son numéricas, pero no pasaría nada si hubiera de texto, booleanas, con missings... Funcionaría igual

# %%
X.dtypes.unique()
# Out:
# array([dtype('float64')], dtype=object)

# %% [markdown]
# <span style='color:blue'>Aplicamos la clase scorecard para sacar el modelo

# %%
modelo = me.scorecard().fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.538507 | pv = 4.92e-32 | Gini train = 83.97% | Gini test = 87.30% ---> Feature selected: mean_concavity
# Step 02 | 0:00:00.836358 | pv = 1.38e-14 | Gini train = 96.82% | Gini test = 97.24% ---> Feature selected: worst_perimeter
# Step 03 | 0:00:01.059373 | pv = 4.31e-06 | Gini train = 98.34% | Gini test = 98.07% ---> Feature selected: worst_texture
# Step 04 | 0:00:01.146291 | pv = 5.11e-04 | Gini train = 98.92% | Gini test = 97.05% ---> Feature selected: worst_smoothness
# Step 05 | 0:00:01.276256 | pv = 1.62e-03 | Gini train = 99.34% | Gini test = 98.51% ---> Feature selected: radius_error
# Step 05 | 0:00:00.000000 | pv = 1.54e-02 | Gini train = 99.25% | Gini test = 98.22% ---> Feature deleted : mean_concavity
# Step 06 | 0:00:01.309671 | pv = 2.28e-03 | Gini train = 99.60% | Gini test = 98.77% ---> Feature selected: worst_concavity
# ------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['worst_perimeter', 'worst_texture', 'worst_smoothness', 'radius_error', 'worst_concavity']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 95.55% de KS y un 99.60% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 95.63% de KS y un 98.77% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Visualizamos la scorecard (si usas notebooks o ventana interactiva en VSC con el tema blanco se verá bien, si no usa display(modelo.scorecard))

# %%
me.pretty_scorecard(modelo)
# Out:
# <style type="text/css">
# #T_ae8be_row0_col0, #T_ae8be_row0_col1, #T_ae8be_row0_col2, #T_ae8be_row0_col3, #T_ae8be_row0_col4, #T_ae8be_row0_col5, #T_ae8be_row0_col6, #T_ae8be_row0_col7, #T_ae8be_row0_col8, #T_ae8be_row0_col9, #T_ae8be_row0_col10, #T_ae8be_row1_col0, #T_ae8be_row1_col1, #T_ae8be_row1_col2, #T_ae8be_row1_col3, #T_ae8be_row1_col4, #T_ae8be_row1_col5, #T_ae8be_row1_col6, #T_ae8be_row1_col7, #T_ae8be_row1_col8, #T_ae8be_row1_col9, #T_ae8be_row1_col10, #T_ae8be_row2_col0, #T_ae8be_row2_col1, #T_ae8be_row2_col2, #T_ae8be_row2_col3, #T_ae8be_row2_col4, #T_ae8be_row2_col5, #T_ae8be_row2_col6, #T_ae8be_row2_col7, #T_ae8be_row2_col8, #T_ae8be_row2_col9, #T_ae8be_row2_col10, #T_ae8be_row3_col0, #T_ae8be_row3_col1, #T_ae8be_row3_col2, #T_ae8be_row3_col3, #T_ae8be_row3_col4, #T_ae8be_row3_col5, #T_ae8be_row3_col6, #T_ae8be_row3_col7, #T_ae8be_row3_col8, #T_ae8be_row3_col9, #T_ae8be_row3_col10, #T_ae8be_row9_col0, #T_ae8be_row9_col1, #T_ae8be_row9_col2, #T_ae8be_row9_col3, #T_ae8be_row9_col4, #T_ae8be_row9_col5, #T_ae8be_row9_col6, #T_ae8be_row9_col7, #T_ae8be_row9_col8, #T_ae8be_row9_col9, #T_ae8be_row9_col10, #T_ae8be_row10_col0, #T_ae8be_row10_col1, #T_ae8be_row10_col2, #T_ae8be_row10_col3, #T_ae8be_row10_col4, #T_ae8be_row10_col5, #T_ae8be_row10_col6, #T_ae8be_row10_col7, #T_ae8be_row10_col8, #T_ae8be_row10_col9, #T_ae8be_row10_col10, #T_ae8be_row11_col0, #T_ae8be_row11_col1, #T_ae8be_row11_col2, #T_ae8be_row11_col3, #T_ae8be_row11_col4, #T_ae8be_row11_col5, #T_ae8be_row11_col6, #T_ae8be_row11_col7, #T_ae8be_row11_col8, #T_ae8be_row11_col9, #T_ae8be_row11_col10, #T_ae8be_row12_col0, #T_ae8be_row12_col1, #T_ae8be_row12_col2, #T_ae8be_row12_col3, #T_ae8be_row12_col4, #T_ae8be_row12_col5, #T_ae8be_row12_col6, #T_ae8be_row12_col7, #T_ae8be_row12_col8, #T_ae8be_row12_col9, #T_ae8be_row12_col10, #T_ae8be_row13_col0, #T_ae8be_row13_col1, #T_ae8be_row13_col2, #T_ae8be_row13_col3, #T_ae8be_row13_col4, #T_ae8be_row13_col5, #T_ae8be_row13_col6, #T_ae8be_row13_col7, #T_ae8be_row13_col8, #T_ae8be_row13_col9, #T_ae8be_row13_col10, #T_ae8be_row19_col0, #T_ae8be_row19_col1, #T_ae8be_row19_col2, #T_ae8be_row19_col3, #T_ae8be_row19_col4, #T_ae8be_row19_col5, #T_ae8be_row19_col6, #T_ae8be_row19_col7, #T_ae8be_row19_col8, #T_ae8be_row19_col9, #T_ae8be_row19_col10, #T_ae8be_row20_col0, #T_ae8be_row20_col1, #T_ae8be_row20_col2, #T_ae8be_row20_col3, #T_ae8be_row20_col4, #T_ae8be_row20_col5, #T_ae8be_row20_col6, #T_ae8be_row20_col7, #T_ae8be_row20_col8, #T_ae8be_row20_col9, #T_ae8be_row20_col10, #T_ae8be_row21_col0, #T_ae8be_row21_col1, #T_ae8be_row21_col2, #T_ae8be_row21_col3, #T_ae8be_row21_col4, #T_ae8be_row21_col5, #T_ae8be_row21_col6, #T_ae8be_row21_col7, #T_ae8be_row21_col8, #T_ae8be_row21_col9, #T_ae8be_row21_col10, #T_ae8be_row22_col0, #T_ae8be_row22_col1, #T_ae8be_row22_col2, #T_ae8be_row22_col3, #T_ae8be_row22_col4, #T_ae8be_row22_col5, #T_ae8be_row22_col6, #T_ae8be_row22_col7, #T_ae8be_row22_col8, #T_ae8be_row22_col9, #T_ae8be_row22_col10, #T_ae8be_row23_col0, #T_ae8be_row23_col1, #T_ae8be_row23_col2, #T_ae8be_row23_col3, #T_ae8be_row23_col4, #T_ae8be_row23_col5, #T_ae8be_row23_col6, #T_ae8be_row23_col7, #T_ae8be_row23_col8, #T_ae8be_row23_col9, #T_ae8be_row23_col10 {
#   background-color: #CCECFF;
# }
# #T_ae8be_row4_col0, #T_ae8be_row4_col1, #T_ae8be_row4_col2, #T_ae8be_row4_col3, #T_ae8be_row4_col4, #T_ae8be_row4_col5, #T_ae8be_row4_col6, #T_ae8be_row4_col7, #T_ae8be_row4_col8, #T_ae8be_row4_col9, #T_ae8be_row4_col10, #T_ae8be_row5_col0, #T_ae8be_row5_col1, #T_ae8be_row5_col2, #T_ae8be_row5_col3, #T_ae8be_row5_col4, #T_ae8be_row5_col5, #T_ae8be_row5_col6, #T_ae8be_row5_col7, #T_ae8be_row5_col8, #T_ae8be_row5_col9, #T_ae8be_row5_col10, #T_ae8be_row6_col0, #T_ae8be_row6_col1, #T_ae8be_row6_col2, #T_ae8be_row6_col3, #T_ae8be_row6_col4, #T_ae8be_row6_col5, #T_ae8be_row6_col6, #T_ae8be_row6_col7, #T_ae8be_row6_col8, #T_ae8be_row6_col9, #T_ae8be_row6_col10, #T_ae8be_row7_col0, #T_ae8be_row7_col1, #T_ae8be_row7_col2, #T_ae8be_row7_col3, #T_ae8be_row7_col4, #T_ae8be_row7_col5, #T_ae8be_row7_col6, #T_ae8be_row7_col7, #T_ae8be_row7_col8, #T_ae8be_row7_col9, #T_ae8be_row7_col10, #T_ae8be_row8_col0, #T_ae8be_row8_col1, #T_ae8be_row8_col2, #T_ae8be_row8_col3, #T_ae8be_row8_col4, #T_ae8be_row8_col5, #T_ae8be_row8_col6, #T_ae8be_row8_col7, #T_ae8be_row8_col8, #T_ae8be_row8_col9, #T_ae8be_row8_col10, #T_ae8be_row14_col0, #T_ae8be_row14_col1, #T_ae8be_row14_col2, #T_ae8be_row14_col3, #T_ae8be_row14_col4, #T_ae8be_row14_col5, #T_ae8be_row14_col6, #T_ae8be_row14_col7, #T_ae8be_row14_col8, #T_ae8be_row14_col9, #T_ae8be_row14_col10, #T_ae8be_row15_col0, #T_ae8be_row15_col1, #T_ae8be_row15_col2, #T_ae8be_row15_col3, #T_ae8be_row15_col4, #T_ae8be_row15_col5, #T_ae8be_row15_col6, #T_ae8be_row15_col7, #T_ae8be_row15_col8, #T_ae8be_row15_col9, #T_ae8be_row15_col10, #T_ae8be_row16_col0, #T_ae8be_row16_col1, #T_ae8be_row16_col2, #T_ae8be_row16_col3, #T_ae8be_row16_col4, #T_ae8be_row16_col5, #T_ae8be_row16_col6, #T_ae8be_row16_col7, #T_ae8be_row16_col8, #T_ae8be_row16_col9, #T_ae8be_row16_col10, #T_ae8be_row17_col0, #T_ae8be_row17_col1, #T_ae8be_row17_col2, #T_ae8be_row17_col3, #T_ae8be_row17_col4, #T_ae8be_row17_col5, #T_ae8be_row17_col6, #T_ae8be_row17_col7, #T_ae8be_row17_col8, #T_ae8be_row17_col9, #T_ae8be_row17_col10, #T_ae8be_row18_col0, #T_ae8be_row18_col1, #T_ae8be_row18_col2, #T_ae8be_row18_col3, #T_ae8be_row18_col4, #T_ae8be_row18_col5, #T_ae8be_row18_col6, #T_ae8be_row18_col7, #T_ae8be_row18_col8, #T_ae8be_row18_col9, #T_ae8be_row18_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_ae8be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae8be_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_ae8be_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_ae8be_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_ae8be_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_ae8be_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_ae8be_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_ae8be_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_ae8be_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_ae8be_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_ae8be_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_ae8be_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae8be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae8be_row0_col0" class="data row0 col0" >worst_perimeter</td>
#       <td id="T_ae8be_row0_col1" class="data row0 col1" >(-inf, 91.69)</td>
#       <td id="T_ae8be_row0_col2" class="data row0 col2" >167</td>
#       <td id="T_ae8be_row0_col3" class="data row0 col3" >0.419598</td>
#       <td id="T_ae8be_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_ae8be_row0_col5" class="data row0 col5" >165</td>
#       <td id="T_ae8be_row0_col6" class="data row0 col6" >0.988024</td>
#       <td id="T_ae8be_row0_col7" class="data row0 col7" >-3.888550</td>
#       <td id="T_ae8be_row0_col8" class="data row0 col8" >2.513895</td>
#       <td id="T_ae8be_row0_col9" class="data row0 col9" >5.210448</td>
#       <td id="T_ae8be_row0_col10" class="data row0 col10" >-48</td>
#     </tr>
#     <tr>
#       <th id="T_ae8be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae8be_row1_col0" class="data row1 col0" >worst_perimeter</td>
#       <td id="T_ae8be_row1_col1" class="data row1 col1" >[91.69, 102.05)</td>
#       <td id="T_ae8be_row1_col2" class="data row1 col2" >58</td>
#       <td id="T_ae8be_row1_col3" class="data row1 col3" >0.145729</td>
#       <td id="T_ae8be_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_ae8be_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_ae8be_row1_col6" class="data row1 col6" >0.913793</td>

# %% [markdown]
# <span style='color:blue'>Podemos guardar la scorecard en un excel con el que enseñar los resultados y poder interpretar bien el sentido y la aportación de cada variable

# %%
modelo.create_excel('scorecard_ejemplo_01.xlsx')
