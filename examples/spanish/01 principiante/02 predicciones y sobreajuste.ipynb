# %% [markdown]
# En este notebook vemos cómo usar los `modelos entrenados` que produce la clase scorecard para hacer predicciones en dos datasets de Kaggle 😎

# %% [markdown]
# <span style='color:blue'>Importamos los módulos

# %%
import sys, numpy as np, pandas as pd, memento as me

# %% [markdown]
# <span style='color:blue'>Cargamos el primer dataset, del **Titanic**

# %%
df_train = pd.read_csv('train titanic.csv')
L = list(me.proc_freq(df_train, 'Survived').frequency)
print('Sobrevivieron {}. Murieron {} (entre ellos Leonardo DiCaprio)'.format(L[1], L[0]))
X, y = df_train.drop('Survived', axis=1), df_train.Survived.values
# Out:
# Sobrevivieron 342. Murieron 549 (entre ellos Leonardo DiCaprio)

# %% [markdown]
# <span style='color:blue'>Sacamos una primera scorecard excluyendo las variables `PassengerId` y `Name`

# %%
modelo_titanic1 = me.scorecard(excluded_vars=['PassengerId', 'Name']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (14) superior al número de variables candidatas (9)
# ------------------------------------------------------------------------------------------------------------------------
# Posibles variables con overfitting: ['Ticket']
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.172926 | pv = 8.59e-39 | Gini train = 55.81% | Gini test = 47.71% ---> Feature selected: Sex
# Step 02 | 0:00:00.296943 | pv = 8.16e-18 | Gini train = 97.35% | Gini test = 45.15% ---> Feature selected: Ticket
# Step 03 | 0:00:00.304477 | pv = 4.92e-03 | Gini train = 98.09% | Gini test = 43.45% ---> Feature selected: SibSp
# Step 04 | 0:00:00.283723 | pv = 8.77e-03 | Gini train = 98.44% | Gini test = 53.52% ---> Feature selected: Cabin
# Step 05 | 0:00:00.287567 | pv = 6.27e-03 | Gini train = 98.75% | Gini test = 50.94% ---> Feature selected: Pclass
# ------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['Sex', 'Ticket', 'SibSp', 'Cabin', 'Pclass']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 93.80% de KS y un 98.75% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 51.72% de KS y un 50.94% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Tremendo batacazo del train al test... Esto es un claro ejemplo de **sobreajuste**, de hecho, el propio log del modelo nos avisa de que cuidado con `Ticket`. Vemos que tiene sentido: es una variable con un iv desmesuradamente alto y con muchísima granularidad

# %%
display(modelo_titanic1.tabla_ivs.head(3))
print('Valores distintos variable Ticket: {}'.format(len(X['Ticket'].value_counts())))
# Out:
#   variable        iv
# 0   Ticket  7.014385
# 1    Cabin  1.529741
# 2      Sex  1.479819
# Valores distintos variable Ticket: 681

# %% [markdown]
# <span style='color:blue'>Sacamos una segunda versión del modelo excluyendo esta variable `Ticket`

# %%
modelo_titanic2 = me.scorecard(excluded_vars=['PassengerId', 'Name', 'Ticket']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (14) superior al número de variables candidatas (8)
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.206477 | pv = 8.59e-39 | Gini train = 55.81% | Gini test = 47.71% ---> Feature selected: Sex
# Step 02 | 0:00:00.278350 | pv = 1.08e-11 | Gini train = 67.27% | Gini test = 64.78% ---> Feature selected: Pclass
# Step 03 | 0:00:00.241625 | pv = 3.03e-08 | Gini train = 72.65% | Gini test = 61.45% ---> Feature selected: Cabin
# Step 04 | 0:00:00.248418 | pv = 2.48e-04 | Gini train = 75.60% | Gini test = 61.67% ---> Feature selected: Age
# ------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['Sex', 'Pclass', 'Cabin', 'Age']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 68.22% de KS y un 75.60% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 55.86% de KS y un 61.67% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Mucho mejor, sin embargo, seguimos teniendo cierto desplome

# %%
print('Caida de Gini de train a test: {:.2f}%'.format(
100*(modelo_titanic2.gini_train - modelo_titanic2.gini_test) / modelo_titanic2.gini_train))
# Out:
# Caida de Gini de train a test: 18.44%

# %% [markdown]
# <span style='color:blue'>Vemos que la diferencia entre tain y test se acentúa tras añadir la variable `Cabin`... Sacamos una tercera versión excluyendo también a `Cabin`

# %%
modelo_titanic3 = me.scorecard(excluded_vars=['PassengerId', 'Name', 'Ticket', 'Cabin']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (14) superior al número de variables candidatas (7)
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.199465 | pv = 8.59e-39 | Gini train = 55.81% | Gini test = 47.71% ---> Feature selected: Sex
# Step 02 | 0:00:00.202337 | pv = 1.08e-11 | Gini train = 67.27% | Gini test = 64.78% ---> Feature selected: Pclass
# Step 03 | 0:00:00.210616 | pv = 5.87e-06 | Gini train = 71.36% | Gini test = 65.31% ---> Feature selected: Age
# ------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['Sex', 'Pclass', 'Age']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 61.55% de KS y un 71.36% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 55.98% de KS y un 65.31% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Este último modelo solo tiene 3 variables.. Bueno y qué pasa?! `#minimalism` 😊

# %%
me.pretty_scorecard(modelo_titanic3, 'green')
# Out:
# <style type="text/css">
# #T_a8f57_row0_col0, #T_a8f57_row0_col1, #T_a8f57_row0_col2, #T_a8f57_row0_col3, #T_a8f57_row0_col4, #T_a8f57_row0_col5, #T_a8f57_row0_col6, #T_a8f57_row0_col7, #T_a8f57_row0_col8, #T_a8f57_row0_col9, #T_a8f57_row0_col10, #T_a8f57_row1_col0, #T_a8f57_row1_col1, #T_a8f57_row1_col2, #T_a8f57_row1_col3, #T_a8f57_row1_col4, #T_a8f57_row1_col5, #T_a8f57_row1_col6, #T_a8f57_row1_col7, #T_a8f57_row1_col8, #T_a8f57_row1_col9, #T_a8f57_row1_col10, #T_a8f57_row5_col0, #T_a8f57_row5_col1, #T_a8f57_row5_col2, #T_a8f57_row5_col3, #T_a8f57_row5_col4, #T_a8f57_row5_col5, #T_a8f57_row5_col6, #T_a8f57_row5_col7, #T_a8f57_row5_col8, #T_a8f57_row5_col9, #T_a8f57_row5_col10, #T_a8f57_row6_col0, #T_a8f57_row6_col1, #T_a8f57_row6_col2, #T_a8f57_row6_col3, #T_a8f57_row6_col4, #T_a8f57_row6_col5, #T_a8f57_row6_col6, #T_a8f57_row6_col7, #T_a8f57_row6_col8, #T_a8f57_row6_col9, #T_a8f57_row6_col10, #T_a8f57_row7_col0, #T_a8f57_row7_col1, #T_a8f57_row7_col2, #T_a8f57_row7_col3, #T_a8f57_row7_col4, #T_a8f57_row7_col5, #T_a8f57_row7_col6, #T_a8f57_row7_col7, #T_a8f57_row7_col8, #T_a8f57_row7_col9, #T_a8f57_row7_col10, #T_a8f57_row8_col0, #T_a8f57_row8_col1, #T_a8f57_row8_col2, #T_a8f57_row8_col3, #T_a8f57_row8_col4, #T_a8f57_row8_col5, #T_a8f57_row8_col6, #T_a8f57_row8_col7, #T_a8f57_row8_col8, #T_a8f57_row8_col9, #T_a8f57_row8_col10, #T_a8f57_row9_col0, #T_a8f57_row9_col1, #T_a8f57_row9_col2, #T_a8f57_row9_col3, #T_a8f57_row9_col4, #T_a8f57_row9_col5, #T_a8f57_row9_col6, #T_a8f57_row9_col7, #T_a8f57_row9_col8, #T_a8f57_row9_col9, #T_a8f57_row9_col10, #T_a8f57_row10_col0, #T_a8f57_row10_col1, #T_a8f57_row10_col2, #T_a8f57_row10_col3, #T_a8f57_row10_col4, #T_a8f57_row10_col5, #T_a8f57_row10_col6, #T_a8f57_row10_col7, #T_a8f57_row10_col8, #T_a8f57_row10_col9, #T_a8f57_row10_col10 {
#   background-color: #CCFFCC;
# }
# #T_a8f57_row2_col0, #T_a8f57_row2_col1, #T_a8f57_row2_col2, #T_a8f57_row2_col3, #T_a8f57_row2_col4, #T_a8f57_row2_col5, #T_a8f57_row2_col6, #T_a8f57_row2_col7, #T_a8f57_row2_col8, #T_a8f57_row2_col9, #T_a8f57_row2_col10, #T_a8f57_row3_col0, #T_a8f57_row3_col1, #T_a8f57_row3_col2, #T_a8f57_row3_col3, #T_a8f57_row3_col4, #T_a8f57_row3_col5, #T_a8f57_row3_col6, #T_a8f57_row3_col7, #T_a8f57_row3_col8, #T_a8f57_row3_col9, #T_a8f57_row3_col10, #T_a8f57_row4_col0, #T_a8f57_row4_col1, #T_a8f57_row4_col2, #T_a8f57_row4_col3, #T_a8f57_row4_col4, #T_a8f57_row4_col5, #T_a8f57_row4_col6, #T_a8f57_row4_col7, #T_a8f57_row4_col8, #T_a8f57_row4_col9, #T_a8f57_row4_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_a8f57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8f57_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_a8f57_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_a8f57_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_a8f57_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_a8f57_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_a8f57_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_a8f57_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_a8f57_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_a8f57_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_a8f57_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_a8f57_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8f57_row0_col0" class="data row0 col0" >Sex</td>
#       <td id="T_a8f57_row0_col1" class="data row0 col1" >['female']</td>
#       <td id="T_a8f57_row0_col2" class="data row0 col2" >221</td>
#       <td id="T_a8f57_row0_col3" class="data row0 col3" >0.354735</td>
#       <td id="T_a8f57_row0_col4" class="data row0 col4" >54</td>
#       <td id="T_a8f57_row0_col5" class="data row0 col5" >167</td>
#       <td id="T_a8f57_row0_col6" class="data row0 col6" >0.755656</td>
#       <td id="T_a8f57_row0_col7" class="data row0 col7" >-1.603189</td>
#       <td id="T_a8f57_row0_col8" class="data row0 col8" >0.894771</td>
#       <td id="T_a8f57_row0_col9" class="data row0 col9" >1.643224</td>
#       <td id="T_a8f57_row0_col10" class="data row0 col10" >124</td>
#     </tr>
#     <tr>
#       <th id="T_a8f57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8f57_row1_col0" class="data row1 col0" >Sex</td>
#       <td id="T_a8f57_row1_col1" class="data row1 col1" >['male']</td>
#       <td id="T_a8f57_row1_col2" class="data row1 col2" >402</td>
#       <td id="T_a8f57_row1_col3" class="data row1 col3" >0.645265</td>
#       <td id="T_a8f57_row1_col4" class="data row1 col4" >330</td>
#       <td id="T_a8f57_row1_col5" class="data row1 col5" >72</td>
#       <td id="T_a8f57_row1_col6" class="data row1 col6" >0.179104</td>
#       <td id="T_a8f57_row1_col7" class="data row1 col7" >1.048248</td>
#       <td id="T_a8f57_row1_col8" class="data row1 col8" >0.585048</td>
#       <td id="T_a8f57_row1_col9" class="data row1 col9" >-1.074424</td>
#       <td id="T_a8f57_row1_col10" class="data row1 col10" >202</td>
#     </tr>
#     <tr>
#       <th id="T_a8f57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8f57_row2_col0" class="data row2 col0" >Pclass</td>
#       <td id="T_a8f57_row2_col1" class="data row2 col1" >(-inf, 1.50)</td>
#       <td id="T_a8f57_row2_col2" class="data row2 col2" >140</td>
#       <td id="T_a8f57_row2_col3" class="data row2 col3" >0.224719</td>
#       <td id="T_a8f57_row2_col4" class="data row2 col4" >55</td>
#       <td id="T_a8f57_row2_col5" class="data row2 col5" >85</td>
#       <td id="T_a8f57_row2_col6" class="data row2 col6" >0.607143</td>
#       <td id="T_a8f57_row2_col7" class="data row2 col7" >-0.909497</td>
#       <td id="T_a8f57_row2_col8" class="data row2 col8" >0.193195</td>
#       <td id="T_a8f57_row2_col9" class="data row2 col9" >1.000029</td>
#       <td id="T_a8f57_row2_col10" class="data row2 col10" >143</td>
#     </tr>
#     <tr>
#       <th id="T_a8f57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8f57_row3_col0" class="data row3 col0" >Pclass</td>
#       <td id="T_a8f57_row3_col1" class="data row3 col1" >[1.50, 2.50)</td>
#       <td id="T_a8f57_row3_col2" class="data row3 col2" >133</td>
#       <td id="T_a8f57_row3_col3" class="data row3 col3" >0.213483</td>
#       <td id="T_a8f57_row3_col4" class="data row3 col4" >66</td>
#       <td id="T_a8f57_row3_col5" class="data row3 col5" >67</td>
#       <td id="T_a8f57_row3_col6" class="data row3 col6" >0.503759</td>
#       <td id="T_a8f57_row3_col7" class="data row3 col7" >-0.489217</td>
#       <td id="T_a8f57_row3_col8" class="data row3 col8" >0.053060</td>
#       <td id="T_a8f57_row3_col9" class="data row3 col9" >0.537914</td>
#       <td id="T_a8f57_row3_col10" class="data row3 col10" >156</td>
#     </tr>
#     <tr>
#       <th id="T_a8f57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8f57_row4_col0" class="data row4 col0" >Pclass</td>
#       <td id="T_a8f57_row4_col1" class="data row4 col1" >[2.50, inf)</td>
#       <td id="T_a8f57_row4_col2" class="data row4 col2" >350</td>
#       <td id="T_a8f57_row4_col3" class="data row4 col3" >0.561798</td>
#       <td id="T_a8f57_row4_col4" class="data row4 col4" >263</td>
#       <td id="T_a8f57_row4_col5" class="data row4 col5" >87</td>
#       <td id="T_a8f57_row4_col6" class="data row4 col6" >0.248571</td>
#       <td id="T_a8f57_row4_col7" class="data row4 col7" >0.632067</td>
#       <td id="T_a8f57_row4_col8" class="data row4 col8" >0.202817</td>
#       <td id="T_a8f57_row4_col9" class="data row4 col9" >-0.694983</td>
#       <td id="T_a8f57_row4_col10" class="data row4 col10" >191</td>
#     </tr>
#     <tr>
#       <th id="T_a8f57_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8f57_row5_col0" class="data row5 col0" >Age</td>
#       <td id="T_a8f57_row5_col1

# %% [markdown]
# <span style='color:blue'>Vamos a usar estos modelos para hacer **predicciones** y subir las submissions resultantes a Kaggle

# %%
df_test = pd.read_csv('test titanic.csv')

# %% [markdown]
# <span style='color:blue'>El método `.predict()` es el responsable de aplicar el modelo a un nuevo dataframe. La variable que contiene la puntuación final es `scorecardpoints`, esta puntuación está calibrada con PEO (points equal odds, donde la tasa de malos es 1/2) en 500 puntos y un PDO (points to double odds) de 20 puntos. También se genera, para cada variable del modelo final, una columna con la puntuación parcial que aporta dicha variable (las columnas 'scr_'). Por último, podemos darle un umbral para sacar la columna 'prediction' con una predicción binaria

# %%
modelo_titanic1.predict(df_test, keep_columns=['PassengerId'], binary_treshold=500)
# Out:
#      PassengerId     Sex              Ticket  SibSp Cabin  Pclass  scr_Sex  \
# 0            892    male              330911      0   NaN       3      145
# 1            893  female              363272      1   NaN       3       38
# 2            894    male              240276      0   NaN       2      145
# 3            895    male              315154      0   NaN       3      145
# 4            896  female             3101298      1   NaN       3       38
# ..           ...     ...                 ...    ...   ...     ...      ...
# 413         1305    male           A.5. 3236      0   NaN       3      145
# 414         1306  female            PC 17758      0  C105       1       38
# 415         1307    male  SOTON/O.Q. 3101262      0   NaN       3      145
# 416         1308    male              359309      0   NaN       3      145
# 417         1309    male                2668      1   NaN       3      145
#
#      scr_Ticket  scr_SibSp  scr_Cabin  scr_Pclass  scorecardpoints  prediction
# 0             3         95        112          81              436           1
# 1             3        134        112          81              368           1
# 2             3         95        112         120              475           1
# 3             3         95        112          81              436           1
# 4             3        134        112          81              368           1
# ..          ...        ...        ...         ...              ...         ...
# 413           3         95        112          81              436           1
# 414         271         95         14         134              552           0
# 415           3         95        112          81              436           1
# 416           3         95        112          81              436           1
# 417           3        134        112          81              475           1
#
# [418 rows x 13 columns]

# %% [markdown]
# <span style='color:blue'>Generamos las submissions como archivos .csv para subirlas a Kaggle

# %%
modelo_titanic1.predict(df_test, keep_columns=['PassengerId'], binary_treshold=500)\
.rename(columns={'prediction': 'Survived'})[['PassengerId', 'Survived']]\
.to_csv('submission_titanic1.csv', index=False) # Score en Kaggle = 0.44258

modelo_titanic2.predict(df_test, keep_columns=['PassengerId'], binary_treshold=500)\
.rename(columns={'prediction': 'Survived'})[['PassengerId', 'Survived']]\
.to_csv('submission_titanic2.csv', index=False) # Score en Kaggle = 0.72727

modelo_titanic3.predict(df_test, keep_columns=['PassengerId'], binary_treshold=500)\
.rename(columns={'prediction': 'Survived'})[['PassengerId', 'Survived']]\
.to_csv('submission_titanic3.csv', index=False) # Score en Kaggle = 0.77272

# %% [markdown]
# <span style='color:blue'>Vamos ahora con otro dataframe de Kaggle similar: **Spaceship Titanic**

# %%
df_train = pd.read_csv('train dimension.csv')
df_train['Transported'] = np.where(df_train['Transported'] == True, 1, 0)
L = list(me.proc_freq(df_train, 'Transported').frequency)
print('Trasportados: {}. No trasportados: {}'.format(L[1], L[0]))
X, y = df_train.drop('Transported', axis=1), df_train.Transported.values
# Out:
# Trasportados: 4378. No trasportados: 4315

# %% [markdown]
# <span style='color:blue'>Tiramos un primer modelo excluyendo las variables `PassengerId` y `Name`

# %%
modelo_spaceship1 = me.scorecard(excluded_vars=['PassengerId', 'Name']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Variables no agrupadas por algún error, seguramente por excesiva concentración en algún valor (> 95%) : ['VIP']
# ------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (14) superior al número de variables candidatas (10)
# ------------------------------------------------------------------------------------------------------------------------
# Posibles variables con overfitting: ['Cabin']
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.494446 | pv = 0.00e+00 | Gini train = 43.60% | Gini test = 44.52% ---> Feature selected: CryoSleep
# Step 02 | 0:00:00.588154 | pv = 0.00e+00 | Gini train = 96.47% | Gini test = 29.89% ---> Feature selected: Cabin
# Step 03 | 0:00:00.756257 | pv = 5.67e-24 | Gini train = 97.12% | Gini test = 37.79% ---> Feature selected: Spa
# Step 04 | 0:00:00.947089 | pv = 3.10e-11 | Gini train = 97.31% | Gini test = 41.95% ---> Feature selected: RoomService
# Step 05 | 0:00:00.989578 | pv = 3.52e-12 | Gini train = 97.49% | Gini test = 43.38% ---> Feature selected: VRDeck
# ------------------------------------------------------------------------------------------------------------------------
# En el siguiente paso ni el KS ni el GINI del train suben más de un 0.20 o un 0.30 respectivamente, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['CryoSleep', 'Cabin', 'Spa', 'RoomService', 'VRDeck']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 90.52% de KS y un 97.49% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 43.76% de KS y un 43.38% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Hacemos tres observaciones:

# %% [markdown]
# 1) <span style='color:blue'>La primera variable que está entrando, `CryoSleep`, es booleana, no hay ningún problema

# %%
me.proc_freq(X, 'CryoSleep')
# Out:
#            frequency   percent
# CryoSleep
# False           5439  0.625676
# True            3037  0.349362
# NaN              217  0.024963

# %% [markdown]
# 2) <span style='color:blue'>Nos avisa de que la variable `VIP` no ha podido agruparse por excesiva concentración y resulta que efectivamente hay un valor que se repite en más del 95% de los casos (podría ser que no fuera superior al 95% en la muestra total y si lo fuera la submuestra del train).<br>Si quisiéramos que el modelo intentará incluir esta variable habría que pedir más flexibilidad en el autogrouping rebajando el umbral mínimo de porcentaje de población por grupo, por ejemplo pasando como argumento a scorecard autogrp_dict_min_pct={'VIP': 0.02})

# %%
me.proc_freq(X, 'VIP')
# Out:
#        frequency   percent
# VIP
# False       8291  0.953756
# True         199  0.022892
# NaN          203  0.023352

# %% [markdown]
# 3) <span style='color:blue'>Al igual que antes nos avisa de posible sobreajuste por `Cabin`, probamos a quitarla

# %%
modelo_spaceship2 = me.scorecard(excluded_vars=['PassengerId', 'Name', 'Cabin']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Variables no agrupadas por algún error, seguramente por excesiva concentración en algún valor (> 95%) : ['VIP']
# ------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (14) superior al número de variables candidatas (9)
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.628840 | pv = 0.00e+00 | Gini train = 43.60% | Gini test = 44.52% ---> Feature selected: CryoSleep
# Step 02 | 0:00:00.692885 | pv = 3.93e-43 | Gini train = 53.24% | Gini test = 53.21% ---> Feature selected: RoomService
# Step 03 | 0:00:00.744656 | pv = 6.15e-45 | Gini train = 58.52% | Gini test = 59.29% ---> Feature selected: Spa
# Step 04 | 0:00:00.796644 | pv = 1.85e-62 | Gini train = 63.38% | Gini test = 64.36% ---> Feature selected: HomePlanet
# Step 05 | 0:00:00.828341 | pv = 1.73e-56 | Gini train = 67.10% | Gini test = 67.69% ---> Feature selected: VRDeck
# Step 06 | 0:00:00.796500 | pv = 6.75e-07 | Gini train = 67.44% | Gini test = 68.33% ---> Feature selected: Destination
# ------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['CryoSleep', 'RoomService', 'Spa', 'HomePlanet', 'VRDeck', 'Destination']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 53.62% de KS y un 67.44% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 55.22% de KS y un 68.33% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>En esta segunda versión ya no teneos sobreajuste ninguno... Sin embargo, podemos echar un vistazo a los p-valores a ver

# %%
modelo_spaceship2.pvalues
# Out:
# {'CryoSleep': 8.501261536649443e-06,
#  'RoomService': 3.7894758380443915e-58,
#  'Spa': 1.3662015415267725e-64,
#  'HomePlanet': 6.614309530531033e-79,
#  'VRDeck': 9.284706908288542e-58,
#  'Destination': 6.749699441276009e-07}

# %% [markdown]
# <span style='color:blue'>Claramente, `CryoSleep` y `Destination` tienen unos pvalores que, si bien sí son superiores al umbral por defecto de 0.01 (porque si no habrían salido en algún paso del stepwise), son muy inferiores a la media del resto de features...<br>Podemos mirar si prescindiendo de alguna de ellas (o de ambas) obtenemos un modelo con métricas similares tanto en train como en test

# %%
features1 = [i for i in modelo_spaceship2.features if i != 'CryoSleep']
# features2 = [i for i in modelo_spaceship2.features if i != 'Destination']
# features3 = [i for i in modelo_spaceship2.features if i != 'CryoSleep' and i!= 'Destination']

modelo_spaceship2_alt1 = me.scorecard(features=features1).fit(X, y)
# modelo_spaceship2_alt2 = me.scorecard(features=features2).fit(X, y)
# modelo_spaceship2_alt3 = me.scorecard(features=features3).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado
# ------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------
# Step 01 | 0:00:00.000000 | pv = 0.00e+00 | Gini train = 36.75% | Gini test = 35.26% ---> Feature selected: RoomService
# Step 02 | 0:00:00.000000 | pv = 0.00e+00 | Gini train = 53.76% | Gini test = 53.85% ---> Feature selected: Spa
# Step 03 | 0:00:00.000000 | pv = 4.76e-76 | Gini train = 61.45% | Gini test = 62.50% ---> Feature selected: HomePlanet
# Step 04 | 0:00:00.000000 | pv = 1.63e-83 | Gini train = 66.82% | Gini test = 67.51% ---> Feature selected: VRDeck
# Step 05 | 0:00:00.000000 | pv = 4.27e-07 | Gini train = 67.53% | Gini test = 68.35% ---> Feature selected: Destination
# ------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['RoomService', 'Spa', 'HomePlanet', 'VRDeck', 'Destination']
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 54.18% de KS y un 67.53% de Gini en la muestra de entrenamiento
# ------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 55.36% de KS y un 68.35% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>En las tres pruebas obtenemos Ginis muy similares... Dejamos como opción 3 la que elimina solo al `CryoSleep` ya que da un Gini ligeramente superior tanto en train como en test respecto a lo que teníamos. Al final cuánto más sencillo sea un modelo, mejor. `#make_it_simple`

# %%
modelo_spaceship3 = modelo_spaceship2_alt1

# %% [markdown]
# <span style='color:blue'>Hacemos las predicciones y subimos los resultados a Kaggle 🚀

# %%
df_test = pd.read_csv('test dimension.csv')

prediction1 = modelo_spaceship1.predict(df_test, keep_columns=['PassengerId'], binary_treshold=500)\
.rename(columns={'prediction': 'Transported'})[['PassengerId', 'Transported']]
prediction1['Transported'] = np.where(prediction1['Transported'] == 1, True, False)
prediction1.to_csv('submission_spaceship1.csv', index=False) # Score en Kaggle = 0.51718

prediction2 = modelo_spaceship2.predict(df_test, keep_columns=['PassengerId'], binary_treshold=500)\
.rename(columns={'prediction': 'Transported'})[['PassengerId', 'Transported']]
prediction2['Transported'] = np.where(prediction2['Transported'] == 1, True, False)
prediction2.to_csv('submission_spaceship2.csv', index=False) # Score en Kaggle = 0.77788

prediction3 = modelo_spaceship3.predict(df_test, keep_columns=['PassengerId'], binary_treshold=500)\
.rename(columns={'prediction': 'Transported'})[['PassengerId', 'Transported']]
prediction3['Transported'] = np.where(prediction3['Transported'] == 1, True, False)
prediction3.to_csv('submission_spaceship3.csv', index=False) # Score en Kaggle = 0.77788

# %% [markdown]
# <span style='color:blue'>Mostramos la scorecard del último modelo, que desempeña igual que el anterior y es más sencillo

# %%
me.pretty_scorecard(modelo_spaceship3, color1='yellow')
# Out:
# <style type="text/css">
# #T_8d0b1_row0_col0, #T_8d0b1_row0_col1, #T_8d0b1_row0_col2, #T_8d0b1_row0_col3, #T_8d0b1_row0_col4, #T_8d0b1_row0_col5, #T_8d0b1_row0_col6, #T_8d0b1_row0_col7, #T_8d0b1_row0_col8, #T_8d0b1_row0_col9, #T_8d0b1_row0_col10, #T_8d0b1_row1_col0, #T_8d0b1_row1_col1, #T_8d0b1_row1_col2, #T_8d0b1_row1_col3, #T_8d0b1_row1_col4, #T_8d0b1_row1_col5, #T_8d0b1_row1_col6, #T_8d0b1_row1_col7, #T_8d0b1_row1_col8, #T_8d0b1_row1_col9, #T_8d0b1_row1_col10, #T_8d0b1_row2_col0, #T_8d0b1_row2_col1, #T_8d0b1_row2_col2, #T_8d0b1_row2_col3, #T_8d0b1_row2_col4, #T_8d0b1_row2_col5, #T_8d0b1_row2_col6, #T_8d0b1_row2_col7, #T_8d0b1_row2_col8, #T_8d0b1_row2_col9, #T_8d0b1_row2_col10, #T_8d0b1_row3_col0, #T_8d0b1_row3_col1, #T_8d0b1_row3_col2, #T_8d0b1_row3_col3, #T_8d0b1_row3_col4, #T_8d0b1_row3_col5, #T_8d0b1_row3_col6, #T_8d0b1_row3_col7, #T_8d0b1_row3_col8, #T_8d0b1_row3_col9, #T_8d0b1_row3_col10, #T_8d0b1_row4_col0, #T_8d0b1_row4_col1, #T_8d0b1_row4_col2, #T_8d0b1_row4_col3, #T_8d0b1_row4_col4, #T_8d0b1_row4_col5, #T_8d0b1_row4_col6, #T_8d0b1_row4_col7, #T_8d0b1_row4_col8, #T_8d0b1_row4_col9, #T_8d0b1_row4_col10, #T_8d0b1_row5_col0, #T_8d0b1_row5_col1, #T_8d0b1_row5_col2, #T_8d0b1_row5_col3, #T_8d0b1_row5_col4, #T_8d0b1_row5_col5, #T_8d0b1_row5_col6, #T_8d0b1_row5_col7, #T_8d0b1_row5_col8, #T_8d0b1_row5_col9, #T_8d0b1_row5_col10, #T_8d0b1_row12_col0, #T_8d0b1_row12_col1, #T_8d0b1_row12_col2, #T_8d0b1_row12_col3, #T_8d0b1_row12_col4, #T_8d0b1_row12_col5, #T_8d0b1_row12_col6, #T_8d0b1_row12_col7, #T_8d0b1_row12_col8, #T_8d0b1_row12_col9, #T_8d0b1_row12_col10, #T_8d0b1_row13_col0, #T_8d0b1_row13_col1, #T_8d0b1_row13_col2, #T_8d0b1_row13_col3, #T_8d0b1_row13_col4, #T_8d0b1_row13_col5, #T_8d0b1_row13_col6, #T_8d0b1_row13_col7, #T_8d0b1_row13_col8, #T_8d0b1_row13_col9, #T_8d0b1_row13_col10, #T_8d0b1_row14_col0, #T_8d0b1_row14_col1, #T_8d0b1_row14_col2, #T_8d0b1_row14_col3, #T_8d0b1_row14_col4, #T_8d0b1_row14_col5, #T_8d0b1_row14_col6, #T_8d0b1_row14_col7, #T_8d0b1_row14_col8, #T_8d0b1_row14_col9, #T_8d0b1_row14_col10, #T_8d0b1_row21_col0, #T_8d0b1_row21_col1, #T_8d0b1_row21_col2, #T_8d0b1_row21_col3, #T_8d0b1_row21_col4, #T_8d0b1_row21_col5, #T_8d0b1_row21_col6, #T_8d0b1_row21_col7, #T_8d0b1_row21_col8, #T_8d0b1_row21_col9, #T_8d0b1_row21_col10, #T_8d0b1_row22_col0, #T_8d0b1_row22_col1, #T_8d0b1_row22_col2, #T_8d0b1_row22_col3, #T_8d0b1_row22_col4, #T_8d0b1_row22_col5, #T_8d0b1_row22_col6, #T_8d0b1_row22_col7, #T_8d0b1_row22_col8, #T_8d0b1_row22_col9, #T_8d0b1_row22_col10, #T_8d0b1_row23_col0, #T_8d0b1_row23_col1, #T_8d0b1_row23_col2, #T_8d0b1_row23_col3, #T_8d0b1_row23_col4, #T_8d0b1_row23_col5, #T_8d0b1_row23_col6, #T_8d0b1_row23_col7, #T_8d0b1_row23_col8, #T_8d0b1_row23_col9, #T_8d0b1_row23_col10 {
#   background-color: #FFFFCC;
# }
# #T_8d0b1_row6_col0, #T_8d0b1_row6_col1, #T_8d0b1_row6_col2, #T_8d0b1_row6_col3, #T_8d0b1_row6_col4, #T_8d0b1_row6_col5, #T_8d0b1_row6_col6, #T_8d0b1_row6_col7, #T_8d0b1_row6_col8, #T_8d0b1_row6_col9, #T_8d0b1_row6_col10, #T_8d0b1_row7_col0, #T_8d0b1_row7_col1, #T_8d0b1_row7_col2, #T_8d0b1_row7_col3, #T_8d0b1_row7_col4, #T_8d0b1_row7_col5, #T_8d0b1_row7_col6, #T_8d0b1_row7_col7, #T_8d0b1_row7_col8, #T_8d0b1_row7_col9, #T_8d0b1_row7_col10, #T_8d0b1_row8_col0, #T_8d0b1_row8_col1, #T_8d0b1_row8_col2, #T_8d0b1_row8_col3, #T_8d0b1_row8_col4, #T_8d0b1_row8_col5, #T_8d0b1_row8_col6, #T_8d0b1_row8_col7, #T_8d0b1_row8_col8, #T_8d0b1_row8_col9, #T_8d0b1_row8_col10, #T_8d0b1_row9_col0, #T_8d0b1_row9_col1, #T_8d0b1_row9_col2, #T_8d0b1_row9_col3, #T_8d0b1_row9_col4, #T_8d0b1_row9_col5, #T_8d0b1_row9_col6, #T_8d0b1_row9_col7, #T_8d0b1_row9_col8, #T_8d0b1_row9_col9, #T_8d0b1_row9_col10, #T_8d0b1_row10_col0, #T_8d0b1_row10_col1, #T_8d0b1_row10_col2, #T_8d0b1_row10_col3, #T_8d0b1_row10_col4, #T_8d0b1_row10_col5, #T_8d0b1_row10_col6, #T_8d0b1_row10_col7, #T_8d0b1_row10_col8, #T_8d0b1_row10_col9, #T_8d0b1_row10_col10, #T_8d0b1_row11_col0, #T_8d0b1_row11_col1, #T_8d0b1_row11_col2, #T_8d0b1_row11_col3, #T_8d0b1_row11_col4, #T_8d0b1_row11_col5, #T_8d0b1_row11_col6, #T_8d0b1_row11_col7, #T_8d0b1_row11_col8, #T_8d0b1_row11_col9, #T_8d0b1_row11_col10, #T_8d0b1_row15_col0, #T_8d0b1_row15_col1, #T_8d0b1_row15_col2, #T_8d0b1_row15_col3, #T_8d0b1_row15_col4, #T_8d0b1_row15_col5, #T_8d0b1_row15_col6, #T_8d0b1_row15_col7, #T_8d0b1_row15_col8, #T_8d0b1_row15_col9, #T_8d0b1_row15_col10, #T_8d0b1_row16_col0, #T_8d0b1_row16_col1, #T_8d0b1_row16_col2, #T_8d0b1_row16_col3, #T_8d0b1_row16_col4, #T_8d0b1_row16_col5, #T_8d0b1_row16_col6, #T_8d0b1_row16_col7, #T_8d0b1_row16_col8, #T_8d0b1_row16_col9, #T_8d0b1_row16_col10, #T_8d0b1_row17_col0, #T_8d0b1_row17_col1, #T_8d0b1_row17_col2, #T_8d0b1_row17_col3, #T_8d0b1_row17_col4, #T_8d0b1_row17_col5, #T_8d0b1_row17_col6, #T_8d0b1_row17_col7, #T_8d0b1_row17_col8, #T_8d0b1_row17_col9, #T_8d0b1_row17_col10, #T_8d0b1_row18_col0, #T_8d0b1_row18_col1, #T_8d0b1_row18_col2, #T_8d0b1_row18_col3, #T_8d0b1_row18_col4, #T_8d0b1_row18_col5, #T_8d0b1_row18_col6, #T_8d0b1_row18_col7, #T_8d0b1_row18_col8, #T_8d0b1_row18_col9, #T_8d0b1_row18_col10, #T_8d0b1_row19_col0, #T_8d0b1_row19_col1, #T_8d0b1_row19_col2, #T_8d0b1_row19_col3, #T_8d0b1_row19_col4, #T_8d0b1_row19_col5, #T_8d0b1_row19_col6, #T_8d0b1_row19_col7, #T_8d0b1_row19_col8, #T_8d0b1_row19_col9, #T_8d0b1_row19_col10, #T_8d0b1_row20_col0, #T_8d0b1_row20_col1, #T_8d0b1_row20_col2, #T_8d0b1_row20_col3, #T_8d0b1_row20_col4, #T_8d0b1_row20_col5, #T_8d0b1_row20_col6, #T_8d0b1_row20_col7, #T_8d0b1_row20_col8, #T_8d0b1_row20_col9, #T_8d0b1_row20_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_8d0b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d0b1_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_8d0b1_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_8d0b1_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_8d0b1_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_8d0b1_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_8d0b1_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_8d0b1_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_8d0b1_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_8d0b1_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_8d0b1_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_8d0b1_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d0b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d0b1_row0_col0" class="data row0 col0" >RoomService</td>
#       <td id="T_8d0b1_row0_col1" class="data row0 col1" >Missing</td>
#       <td id="T_8d0b1_row0_col2" class="data row0 col2" >126</td>
#       <td id="T_8d0b1_row0_col3" class="data row0 col3" >0.020707</td>
#       <td id="T_8d0b1_row0_col4" class="data row0 col4" >73</td>
#       <td id="T_8d0b1_row0_col5" class="data row0 col5" >53</td>
#       <td id="T_8d0b1_row0_col6" class="data row0 col6" >0.420635</td>
#       <td id="T_8d0b1_row0_col7" class="data row0 col7" >0.334958</td>
#       <td id="T_8d0b1_row0_col8" class="data row0 col8" >0.002305</td>
#       <td id="T_8d0b1_row0_col9" class="data row0 col9" >-0.262972</td>
#       <td id="T_8d0b1_row0_col10" class="data row0 col10" >107</td>
#     </tr>
#     <tr>
#       <th id="T_8d0b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d0b1_row1_col0" class="data row1 col0" >RoomService</td>
#       <td id="T_8d0b1_row1_col1" class="data row1 col1" >(-inf, 0.50)</td>
#       <td id="T_8d0b1_row1_col2" class="data row1 col2" >3870</td>
#       <td id="T_8d0b1_row1_col3" class="data row1 col3" >0.635990</td>
#       <td id="T_8d0b1_row1_col4" class="data row1 col4" >1408</td>
#       <td id="T_8d0b1_row1_col5" class="data row1 col5" >2462</td>
#       <td id="T_8d0b1_row1_col6" class="data row1 col6" >0.636176</td>
#       <td i
